# %%
import pandas as pd
import os
from typing import Dict, List, Optional
import numpy as np

# Fungsi 1: Konversi Excel ke CSV dan Load ke Memory
def convert_excel_to_csv_and_load(excel_file_path: str, output_dir: str = 'inventory_csv_data') -> Dict[str, pd.DataFrame]:
    """
    Mengkonversi setiap sheet dalam file Excel menjadi file CSV 
    dan memuatnya ke dalam memory sebagai dictionary of DataFrames.
    
    Args:
        excel_file_path (str): Path ke file .xlsx.
        output_dir (str): Nama folder untuk menyimpan file CSV.
        
    Returns:
        Dict[str, pd.DataFrame]: Dictionary berisi {sheet_name: DataFrame}.
    """
    print("="*60)
    print("🚀 EXCEL TO CSV CONVERTER & DATAFRAME LOADER")
    print("="*60)
    
    # 1. Pastikan file Excel ada
    if not os.path.exists(excel_file_path):
        print(f"❌ Error: File tidak ditemukan di path: {excel_file_path}")
        return {}
    
    # 2. Buat folder output
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
        print(f"✓ Created folder: {output_dir}")
        
    # 3. Baca semua sheets dari Excel
    try:
        xls = pd.ExcelFile(excel_file_path)
        sheet_names = xls.sheet_names
        print(f"✓ Found {len(sheet_names)} sheets in {os.path.basename(excel_file_path)}")
    except Exception as e:
        print(f"❌ Error reading Excel file: {e}")
        return {}
        
    all_dataframes: Dict[str, pd.DataFrame] = {}
    
    print("\n💾 Processing and Exporting Sheets to CSV...")
    for sheet_name in sheet_names:
        print(f"   Processing sheet: {sheet_name}...", end='\r')
        try:
            # Baca sheet ke DataFrame
            df = xls.parse(sheet_name)
            
            # Simpan ke CSV
            csv_file_path = os.path.join(output_dir, f"{sheet_name}.csv")
            df.to_csv(csv_file_path, index=False)
            
            # Simpan ke dictionary untuk analisis
            all_dataframes[sheet_name] = df
            print(f"   ✅ {sheet_name}: {len(df):,} rows, {len(df.columns)} columns. Exported to {csv_file_path}")
            
        except Exception as e:
            print(f"   ❌ Failed to process sheet {sheet_name}: {e}")
            
    print("\n✅ All Sheets Processed and Loaded into Memory!")
    return all_dataframes

# Fungsi 2: Menampilkan Ringkasan Komprehensif dari DataFrames
def display_comprehensive_dataframe_summary(dataframes: Dict[str, pd.DataFrame]):
    """
    Menampilkan ringkasan terstruktur dari semua DataFrames.
    
    Args:
        dataframes (Dict[str, pd.DataFrame]): Dictionary of DataFrames.
    """
    print("\n" + "="*80)
    print("🔍 COMPREHENSIVE DATAFRAME STRUCTURE ANALYSIS")
    print("="*80)
    
    if not dataframes:
        print("No DataFrames to display.")
        return
        
    for sheet_name, df in dataframes.items():
        print("\n" + "="*80)
        print(f"📊 Sheet: {sheet_name}")
        print("="*80)
        
        total_rows, total_cols = df.shape
        print(f"📏 Shape: {total_rows:,} rows × {total_cols} columns")
        print("-" * 50)
        
        summary_list = []
        for col in df.columns:
            # Hitung statistik dasar
            dtype = df[col].dtype
            non_null_count = df[col].count()
            null_count = total_rows - non_null_count
            null_percentage = (null_count / total_rows) * 100 if total_rows > 0 else 0.0
            
            # Analisis Nilai Unik
            unique_count = df[col].nunique()
            
            # Ambil nilai unik teratas untuk kolom dengan sedikit kategori
            unique_values = "Too many unique values"
            if unique_count <= 20 and unique_count > 0:
                # Mengambil value_counts() dan memformatnya
                top_values = df[col].value_counts().head(5).index.tolist()
                unique_values = str(top_values)
            elif unique_count == 0:
                unique_values = "All Null/Zero"
            elif unique_count == 1:
                unique_values = f"Single Value: {df[col].iloc[0]}"

            # Catat ringkasan
            summary_list.append({
                'Column': col,
                'Type': dtype,
                'Non-Null': f"{non_null_count:,}",
                'Null %': f"{null_percentage:.2f}%",
                'Unique Count': unique_count,
                'Top/Unique Values Sample': unique_values[:100] # Batasi tampilan
            })

        # Konversi ke DataFrame Pandas untuk tampilan yang bagus
        summary_df = pd.DataFrame(summary_list)
        
        # Atur lebar tampilan (opsional, untuk tampilan di console)
        pd.set_option('display.max_rows', None)
        pd.set_option('display.max_columns', None)
        pd.set_option('display.width', 1000)
        pd.set_option('display.colheader_justify', 'left')
        
        # Tampilkan DataFrame
        print(summary_df.to_string())

# ====================================================================
# MAIN EXECUTION
# ====================================================================
if __name__ == "__main__":
    # Ganti dengan path file .xlsx Anda yang sudah di-download
    EXCEL_FILE_PATH = 'sales_performance_analytics.xlsx'
    
    # Folder tempat menyimpan CSV
    CSV_OUTPUT_FOLDER = 'data_project2'
    
    # 1. Konversi dan Load data ke memory
    loaded_dataframes = convert_excel_to_csv_and_load(EXCEL_FILE_PATH, CSV_OUTPUT_FOLDER)
    
    # 2. Tampilkan struktur data yang komprehensif
    display_comprehensive_dataframe_summary(loaded_dataframes)

# Catatan: Jika Anda ingin menyesuaikan kolom yang ditampilkan di summary, 
# ubah list 'summary_list' dan DataFrame 'summary_df' di fungsi 
# 'display_comprehensive_dataframe_summary'.
# Out:
# ============================================================
# 🚀 EXCEL TO CSV CONVERTER & DATAFRAME LOADER
# ============================================================
# ✓ Created folder: data_project2
# ✓ Found 10 sheets in sales_performance_analytics.xlsx
#
# 💾 Processing and Exporting Sheets to CSV...
#    ✅ 1_RFM_Analysis: 814 rows, 20 columns. Exported to data_project2\1_RFM_Analysis.csv
#    ✅ 2_Customer_Segments: 10 rows, 8 columns. Exported to data_project2\2_Customer_Segments.csv
#    ✅ 3_Market_Basket: 21 rows, 7 columns. Exported to data_project2\3_Market_Basket.csv
#    ✅ 4_Product_Associations: 16 rows, 6 columns. Exported to data_project2\4_Product_Associations.csv
#    ✅ 5_Sales_Details: 10,488 rows, 21 columns. Exported to data_project2\5_Sales_Details.csv
#    ✅ 6_Sales_By_Customer: 814 rows, 12 columns. Exported to data_project2\6_Sales_By_Customer.csv
#    ✅ 7_Sales_By_Product: 1,658 rows, 10 columns. Exported to data_project2\7_Sales_By_Product.csv
#    ✅ 8_Customer_Master: 864 rows, 8 columns. Exported to data_project2\8_Customer_Master.csv
#    ✅ 9_Item_Master: 2,246 rows, 10 columns. Exported to data_project2\9_Item_Master.csv
#    ✅ 10_Summary_Stats: 32 rows, 2 columns. Exported to data_project2\10_Summary_Stats.csv
#
# ✅ All Sheets Processed and Loaded into Memory!
#
# ================================================================================
# 🔍 COMPREHENSIVE DATAFRAME STRUCTURE ANALYSIS
# ================================================================================
#
# ================================================================================
# 📊 Sheet: 1_RFM_Analysis
# ================================================================================
# 📏 Shape: 814 rows × 20 columns
# --------------------------------------------------
#    Column                 Type     Non-Null Null %   Unique Count Top/Unique Values Sample
# 0             customer_id    int64  814       0.00%  814                                                                                         Too many unique values
# 1      last_purchase_date   object  521      36.00%  176                                                                                         Too many unique values
# 2     first_purchase_date   object  521      36.00%  183                                                                                         Too many unique values
# 3       transaction_count    int64  814       0.00%   46                                                                                         Too many unique values
# 4            total_orders    int64  814       0.00%   53                                                                                         Too many unique values
# 5                monetary  float64  814       0.00%  795                                                                                         Too many unique values
# 6   total_items_purchased    int64  814       0.00%  230                                                                                         Too many unique values
# 7           customer_name   object  814       0.00%  813                                                                                         Too many unique values
# 8            recency_days    int64  814       0.00%  177                                                                                         Too many unique values
# 9               frequency    int64  814       0.00%   53                                                                                         Too many unique values
# 10        avg_order_value  float64  814       0.00%  792                                                                                         Too many unique values
# 11      customer_age_days    int64  814       0.00%  180                                                                                         Too many unique values
# 12                r_score    int64  814       0.00%    5                                                                                                [4, 2, 5, 1, 3]
# 13                f_score    int64  814       0.00%    5                                                                                                [5, 4, 1, 2, 3]
# 14                m_score    int64  814       0.00%    5                                                                                                [4, 5, 2, 1, 3]
# 15              rfm_score    int64  814       0.00%  105                                                                                         Too many unique values
# 16      rfm_score_numeric    int64  814       0.00%   13                                                                                                [7, 5, 9, 8, 4]
# 17                segment   object  814       0.00%   10                                     ['Other', 'Loyal Customers', 'Champions', 'Hibernating', 'About To Sleep']
# 18     recommended_action   object  650      20.15%    9           ['Upsell higher value products. Engage them.', 'Reward them. Can be early adopters for new products.
# 19       segment_priority  float64  650      20.15%    9                                                                                     [9.0, 10.0, 1.0, 2.0, 6.0]
#
# ================================================================================
# 📊 Sheet: 2_Customer_Segments
# ================================================================================
# 📏 Shape: 10 rows × 8 columns
# --------------------------------------------------
#   Column            Type     Non-Null Null %  Unique Count Top/Unique Values Sample
# 0           segment   object  10       0.00%  10            ['Champions', 'Loyal Customers', 'At Risk', 'Potential Loyalist', 'Need Attention']
# 1    customer_count    int64  10       0.00%  10                                                                         [154, 158, 52, 55, 35]
# 2  avg_recency_days  float64  10       0.00%  10                                                      [90.79, 333.77, 8749.96, 147.85, 5771.97]
# 3     avg_frequency  float64  10       0.00%   6                                                                 [1.0, 1.74, 21.92, 5.34, 2.98]
# 4     total_revenue  float64  10       0.00%  10                  [156670286097.86, 72325027932.63, 17591117457.12, 1113334685.97, 818971010.0]
# 5      avg_monetary  float64  10       0.00%  10                          [1017339520.12, 457753341.35, 338290720.33, 20242448.84, 23399171.71]
# 6      customer_pct  float64  10       0.00%  10                                                                    [18.9, 19.4, 6.4, 6.8, 4.3]
# 7       revenue_pct  float64  10       0.00%   9                                                                    [0.0, 57.2, 26.4, 6.4, 0.4]
#
# ================================================================================
# 📊 Sheet: 3_Market_Basket
# ================================================================================
# 📏 Shape: 21 rows × 7 columns
# --------------------------------------------------
#   Column            Type     Non-Null Null %  Unique Count Top/Unique Values Sample
# 0  antecedent_items   object  21       0.00%  15            ['23080128. IHC Digital Conferen', '02170477.HWA-01ideashare Key', '21156005. WB1M0BRACKET01Wall M',
# 1  consequent_items   object  21       0.00%  14            ['02170477.HWA-01ideashare Key', '23080128. IHC Digital Conferen', '21156005. WB1M0BRACKET01Wall M',
# 2           support  float64  21       0.00%   6            [0.01108647450110865, 0.01419068736141907, 0.02660753880266075, 0.01729490022172949, 0.0372505543237
# 3        confidence  float64  21       0.00%  11                                         [1.0, 0.7812500000000001, 0.48, 0.6818181818181818, 0.4545454545454546]
# 4              lift  float64  21       0.00%   8                                        [70.46875, 12.3, 3.87314439946019, 8.200000000000001, 7.179183673469389]
# 5     support_count    int64  21       0.00%   6                                                                                            [25, 32, 60, 39, 84]
# 6     lift_category   object  21       0.00%   1                                                                                                      ['Strong']
#
# ================================================================================
# 📊 Sheet: 4_Product_Associations
# ================================================================================
# 📏 Shape: 16 rows × 6 columns
# --------------------------------------------------
#   Column          Type     Non-Null Null %  Unique Count Top/Unique Values Sample
# 0    product_1_id    int64  16       0.00%  10                                                                                     [651, 320, 342, 360, 19356]
# 1  product_1_name   object  16       0.00%  10            ['RG-ES209GC-P', 'RG-AP820-L(V3)', 'RG-EW1200G-PRO', 'RG-RAP2200E', '21156005. WB1M0BRACKET01Wall Mo
# 2    product_2_id    int64  16       0.00%  11                                                                                     [379, 326, 360, 19452, 652]
# 3  product_2_name   object  16       0.00%  11                    ['RG-EW1200', 'RG-E120(GE)', 'RG-RAP2200E', '02170477.HWA-01ideashare Key', 'RG-RAP2260(G)']
# 4         support  float64  16       0.00%   9            [0.01108647450110865, 0.01729490022172949, 0.01419068736141907, 0.03725055432372506, 0.0266075388026
# 5   support_count    int64  16       0.00%   9                                                                                            [25, 39, 32, 84, 60]
#
# ================================================================================
# 📊 Sheet: 5_Sales_Details
# ================================================================================
# 📏 Shape: 10,488 rows × 21 columns
# --------------------------------------------------
#    Column             Type     Non-Null Null %    Unique Count Top/Unique Values Sample
# 0          invoice_id    int64  10,488     0.00%  5031                                                                                        Too many unique values
# 1      invoice_number   object  10,488     0.00%  5031                                                                                        Too many unique values
# 2    transaction_date   object   4,102    60.89%   204                                                                                        Too many unique values
# 3         customer_id    int64  10,488     0.00%   814                                                                                        Too many unique values
# 4       customer_name   object  10,488     0.00%   813                                                                                        Too many unique values
# 5       salesman_name  float64       0   100.00%     0                                                                                                 All Null/Zero
# 6           branch_id    int64  10,488     0.00%     1                                                                                                          [50]
# 7         branch_name   object  10,488     0.00%     1                                                                                              ['Kantor Pusat']
# 8       currency_code   object  10,488     0.00%     2          ["{'symbol': 'Rp', 'defaultArAccountId': 158, 'code': 'IDR', 'defaultSalesDiscAccountId': 224, 'optL
# 9          product_id    int64  10,488     0.00%  1658                                                                                        Too many unique values
# 10       product_code   object  10,488     0.00%  1658                                                                                        Too many unique values
# 11       product_name   object  10,488     0.00%  1533                                                                                        Too many unique values
# 12           quantity    int64  10,488     0.00%   164                                                                                        Too many unique values
# 13         unit_price  float64  10,488     0.00%  3722                                                                                        Too many unique values
# 14       total_amount  float64  10,488     0.00%  5345                                                                                        Too many unique values
# 15           discount    int64  10,488     0.00%     1                                                                                                           [0]
# 16       warehouse_id  float64  10,120     3.51%     5                                                                            [50.0, 150.0, 200.0, 100.0, 300.0]
# 17     warehouse_name  float64       0   100.00%     0                                                                                                 All Null/Zero
# 18               unit  float64       0   100.00%     0                                                                                                 All Null/Zero
# 19  customer_category  float64       0   100.00%     0                                                                                                 All Null/Zero
# 20   product_category  float64       0   100.00%     0                                                                                                 All Null/Zero
#
# ================================================================================
# 📊 Sheet: 6_Sales_By_Customer
# ================================================================================
# 📏 Shape: 814 rows × 12 columns
# --------------------------------------------------
#    Column                 Type     Non-Null Null %   Unique Count Top/Unique Values Sample
# 0             customer_id    int64  814       0.00%  814           Too many unique values
# 1      last_purchase_date   object  521      36.00%  176           Too many unique values
# 2     first_purchase_date   object  521      36.00%  183           Too many unique values
# 3       transaction_count    int64  814       0.00%   46           Too many unique values
# 4            total_orders    int64  814       0.00%   53           Too many unique values
# 5                monetary  float64  814       0.00%  795           Too many unique values
# 6   total_items_purchased    int64  814       0.00%  230           Too many unique values
# 7           customer_name   object  814       0.00%  813           Too many unique values
# 8            recency_days    int64  814       0.00%  177           Too many unique values
# 9               frequency    int64  814       0.00%   53           Too many unique values
# 10        avg_order_value  float64  814       0.00%  792           Too many unique values
# 11      customer_age_days    int64  814       0.00%  180           Too many unique values
#
# ================================================================================
# 📊 Sheet: 7_Sales_By_Product
# ================================================================================
# 📏 Shape: 1,658 rows × 10 columns
# --------------------------------------------------
#   Column                    Type     Non-Null Null %    Unique Count Top/Unique Values Sample
# 0                product_id    int64  1,658      0.00%  1658          Too many unique values
# 1              product_code   object  1,658      0.00%  1658          Too many unique values
# 2              product_name   object  1,658      0.00%  1533          Too many unique values
# 3       total_quantity_sold    int64  1,658      0.00%   225          Too many unique values
# 4             total_revenue  float64  1,658      0.00%  1355          Too many unique values
# 5               order_count    int64  1,658      0.00%    76          Too many unique values
# 6          unique_customers    int64  1,658      0.00%    50          Too many unique values
# 7                 avg_price  float64  1,658      0.00%  1325          Too many unique values
# 8          product_category  float64      0    100.00%     0                   All Null/Zero
# 9  revenue_contribution_pct  float64  1,658      0.00%  1355          Too many unique values
#
# ================================================================================
# 📊 Sheet: 8_Customer_Master
# ================================================================================
# 📏 Shape: 864 rows × 8 columns
# --------------------------------------------------
#   Column        Type     Non-Null Null %    Unique Count Top/Unique Values Sample
# 0            id    int64  864        0.00%  864           Too many unique values
# 1          name   object  864        0.00%  862           Too many unique values
# 2    customerNo   object  864        0.00%  864           Too many unique values
# 3    categoryId  float64    0      100.00%    0                    All Null/Zero
# 4  categoryName  float64    0      100.00%    0                    All Null/Zero
# 5         email   object   22       97.45%   21           Too many unique values
# 6         phone   object  176       79.63%  171           Too many unique values
# 7          city  float64    0      100.00%    0                    All Null/Zero
#
# ================================================================================
# 📊 Sheet: 9_Item_Master
# ================================================================================
# 📏 Shape: 2,246 rows × 10 columns
# --------------------------------------------------
#   Column            Type     Non-Null Null %    Unique Count Top/Unique Values Sample
# 0                id    int64  2,246      0.00%  2246                                      Too many unique values
# 1                no   object  2,246      0.00%  2246                                      Too many unique values
# 2              name   object  2,246      0.00%  1999                                      Too many unique values
# 3          itemType   object  2,246      0.00%     4          ['INVENTORY', 'NON_INVENTORY', 'SERVICE', 'GROUP']
# 4    itemCategoryId  float64      0    100.00%     0                                               All Null/Zero
# 5  itemCategoryName  float64      0    100.00%     0                                               All Null/Zero
# 6           avgCost    int64  2,246      0.00%     1                                                         [0]
# 7         unitPrice  float64  2,246      0.00%    37                                      Too many unique values
# 8              unit  float64      0    100.00%     0                                               All Null/Zero
# 9             upcNo   object      1     99.96%     1                                               ['ALTAI-025']
#
# ================================================================================
# 📊 Sheet: 10_Summary_Stats
# ================================================================================
# 📏 Shape: 32 rows × 2 columns
# --------------------------------------------------
#   Column  Type    Non-Null Null %  Unique Count Top/Unique Values Sample
# 0  Metric  object  32       0.00%  32            Too many unique values
# 1   Value  object  32       0.00%  28            Too many unique values
